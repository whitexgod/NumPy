# %%
def linspace(Lower_limit,Upper_limit,divisions) :
   #taking input from the user
    steps_to_skip=(Upper_limit-Lower_limit)/(divisions-1) 
     #finding out the difference 
    array=[]  
    #creating an empty list
    temp=start
      #storing the value in a variable 
    for i in range (div) : 
      #creating a for loop for creating the array/list 
          array.append(temp)
          temp=temp+steps
    print(array)
     #creating the final array to be printed

# %%
linspace(1,10,2)
# Out:
# [1, 10.0]

# %%
linspace(1,10,3)
# Out:
# [1, 5.5, 10.0]
